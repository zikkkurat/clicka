# %%
import numpy as np
import requests
from tqdm import tqdm_notebook
import pandas as pd

# %%
r = requests.get('https://api.hh.ru/vacancies?employer_id=107434').json() 
r
# Out:
# {'items': [{'id': '43764699',
#    'premium': False,
#    'name': 'Начальник транспортного отдела (Египет)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-04-09T16:09:40+0300',
#    'created_at': '2021-04-09T16:09:40+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=43764699',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/43764699?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/43764699',
#    'relations': [],
#    'employer': {'id': '107434',
#     'name': 'ИНЖИНИРИНГОВЫЙ ДИВИЗИОН ГОСКОРПОРАЦИИ «РОСАТОМ»',
#     'url': 'https://api.hh.ru/employers/107434',
# ...

# %%
vac = []
for i in tqdm_notebook(range(0, 5)):
    vac.append(requests.get("https://api.hh.ru/vacancies?employer_id=107434", params={'page': i, 'per_page':20}).json())
# Out:
# C:\Users\tariell\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
pac=[]
for i in range(0, 5):
    for j in range(0, 20):
        pac.append(vac[i]['items'][j]['alternate_url'])
lili = [re.sub(r'[^0-9]', '', e) for e in pac]               
vah = []
for i in tqdm_notebook(range(0, 5)):
    for j in tqdm_notebook(range(0, 20)):
        vah.append(requests.get("https://api.hh.ru/vacancies?employer_id=107434", params={'page': i, 'per_page':20}).json()['items'][j]['alternate_url'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9d3990570927> in <module>
#       3     for j in range(0, 20):
#       4         pac.append(vac[i]['items'][j]['alternate_url'])
# ----> 5 lili = [re.sub(r'[^0-9]', '', e) for e in pac]
#       6 vah = []
#       7 for i in tqdm_notebook(range(0, 5)):
#
# <ipython-input-12-9d3990570927> in <listcomp>(.0)
#       3     for j in range(0, 20):
#       4         pac.append(vac[i]['items'][j]['alternate_url'])
# ----> 5 lili = [re.sub(r'[^0-9]', '', e) for e in pac]
#       6 vah = []
#       7 for i in tqdm_notebook(range(0, 5)):
#
# NameError: name 're' is not defined

# %%
from parse_hh_data import download, parse
vacancy = download.vacancy("43696650")
print(vacancy)
# Out:
# {'id': '43696650', 'premium': False, 'billing_type': {'id': 'standard', 'name': 'Стандарт'}, 'relations': [], 'name': 'Data scientist / Team Lead Data Science', 'insider_interview': None, 'response_letter_required': False, 'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'}, 'salary': None, 'type': {'id': 'open', 'name': 'Открытая'}, 'address': None, 'allow_messages': True, 'site': {'id': 'hh', 'name': 'hh.ru'}, 'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'}, 'schedule': {'id': 'remote', 'name': 'Удаленная работа'}, 'employment': {'id': 'full', 'name': 'Полная занятость'}, 'department': None, 'contacts': None, 'description': '<p>Привет! Мы работаем с сотнями предприятий атомной отрасли – помогаем с точки зрения ИТ инфраструктуры, прикладного ПО и активно набираем продуктовые команды. Аудитория наших решений – сотни тысяч пользователей.</p> <p>Мы приглашаем специалистов в области машинного обучения для работы над множеством проектов, связанных
# ...

# %%
from parse_hh_data import download, parse
vacancy = download.vacancy("43154949")
print(vacancy)
# Out:
# {'id': '43154949', 'premium': False, 'billing_type': {'id': 'standard', 'name': 'Стандарт'}, 'relations': [], 'name': 'Backend-developer Python', 'insider_interview': None, 'response_letter_required': False, 'area': {'id': '99', 'name': 'Уфа', 'url': 'https://api.hh.ru/areas/99'}, 'salary': None, 'type': {'id': 'open', 'name': 'Открытая'}, 'address': None, 'allow_messages': True, 'site': {'id': 'hh', 'name': 'hh.ru'}, 'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'}, 'schedule': {'id': 'remote', 'name': 'Удаленная работа'}, 'employment': {'id': 'full', 'name': 'Полная занятость'}, 'department': None, 'contacts': None, 'description': '<p>Привет! Мы работаем с сотнями предприятий атомной отрасли – помогаем с точки зрения ИТ инфраструктуры, прикладного ПО и активно набираем продуктовые команды. Аудитория наших решений – сотни тысяч пользователей.</p> <p><strong>Что мы </strong><strong>делаем</strong><strong>: </strong></p> <ul> <li>Создаем новый продукт для внутренней 
# ...
