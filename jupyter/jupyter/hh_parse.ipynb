# %%
pip install parse-hh-data
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from parse_hh_data import download, parse

vacancy = download.vacancy("43064926")

print(vacancy)
# Out:
# {'id': '43064926', 'premium': False, 'billing_type': {'id': 'standard', 'name': 'Стандарт'}, 'relations': [], 'name': 'Ведущий специалист по инфраструктуре', 'insider_interview': None, 'response_letter_required': False, 'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'}, 'salary': None, 'type': {'id': 'open', 'name': 'Открытая'}, 'address': None, 'allow_messages': True, 'site': {'id': 'hh', 'name': 'hh.ru'}, 'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'}, 'schedule': {'id': 'fullDay', 'name': 'Полный день'}, 'employment': {'id': 'full', 'name': 'Полная занятость'}, 'department': None, 'contacts': None, 'description': '<strong>Обязанности:</strong> <ul> <li>Координация работ и техническая экспертиза по внедрению и сопровождению комплексных ИТ-решений для предприятий атомной отрасли;</li> <li>Разработка комплектов технической документации на ИТ-решения;</li> <li>Разработка сопроводительной документации, инструкций, технических решений;</li> <l
# ...

# %% [raw]
# import numpy as np
# import requests
# from tqdm import tqdm_notebook
# import pandas as pd
# r = requests.get('https://api.hh.ru/vacancies?employer_id=577743').json()
# r

# %%
import numpy as np
import requests
from tqdm import tqdm_notebook
import pandas as pd
r = requests.get('https://api.hh.ru/vacancies?employer_id=577743').json() 
r
# Out:
# {'items': [{'id': '43838838',
#    'premium': False,
#    'name': 'Главный специалист Проектного офиса "Росатом 2.0"',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-04-13T11:52:12+0300',
#    'created_at': '2021-04-13T11:52:12+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=43838838',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/43838838?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/43838838',
#    'relations': [],
#    'employer': {'id': '577743',
#     'name': 'Госкорпорация Росатом',
#     'url': 'https://api.hh.ru/employers/577743',
# ...

# %%
from parse_hh_data import download, parse
resume = download.resume("d1c348d0000532bdef0039ed1f4b63784e6b71")
resume = parse.resume(resume)
resume
# Out:
# {'birth_date': '29\xa0августа\xa01992',
#  'gender': 'Мужчина',
#  'area': 'Екатеринбург',
#  'title': 'Менеджер по работе с клиентами',
#  'specialization': [{'name': 'Дилерские сети', 'profarea_name': 'Продажи'},
#   {'name': 'Дистрибуция', 'profarea_name': 'Продажи'},
#   {'name': 'Менеджер по работе с клиентами', 'profarea_name': 'Продажи'}],
#  'salary': {'amount': 65000, 'currency': 'руб.'},
#  'education_level': 'Высшее образование',
#  'education': [{'year': 2015,
#    'name': 'Уральский государственный горный университет, Екатеринбург',
#    'organization': 'Инженерно-экономический факультет, Экономка и управление на предприятии '}],
#  'language': [{'name': 'Русский', 'level': 'Родной'},
#   {'name': 'Английский', 'level': 'B2 - Средне-продвинутый'}],
#  'experience': [{'start': '01-09-2020',
#    'end': None,
#    'position': 'Менеджер по работе с клиентами среднего бизнеса',
# ...

# %%
from parse_hh_data import download, parse
r_ids = download.resume_ids("specialist", 30, 20, 20)
r_ids
# Out:
# ['aa9495c900053c63e40039ed1f474154346c4e',
#  'eecdeee0000469c99a0039ed1f684930377a59',
#  '8f275dde0007ea836d0039ed1f47456251797a',
#  'c0aa704a00084a48af0039ed1f43736f6d7732',
#  '4ebc60aa00070ba7d40039ed1f324355566832',
#  '02fa6b83000426bd490039ed1f547755783979',
#  '0c2b85f00007f362210039ed1f48577441774f',
#  '71f30fe70008055d180039ed1f386c34517853',
#  '59bd810300057837bd0039ed1f353073447131',
#  '7c9ce6ec00024062080039ed1f6a53524a684e',
#  '29574c5600079edfcd0039ed1f487761377a4a',
#  '870435220007e06bd30039ed1f7a6b5237506d',
#  '6cc952120000b6c59b0039ed1f736563726574',
#  'c9e9f33200084a81280039ed1f65495454784f',
#  '31c9b13900011e77be0039ed1f7450314a7675',
#  '4c069b1200085429770039ed1f7a39686a4a4b',
#  'c064ec8b0004422cf80039ed1f4c6253746831',
#  '88d2a84900042d74430039ed1f476f41356d31',
#  'a8a7a7d7000828b7f20039ed1f706368586b77',
#  '34071646000850b4b40039ed1f745077343139',
#  'fb04781300084cb7860039ed1f6d4b62716b55',
#  '370bf48800076394c50039ed1f36724c4e4838',
# ...

# %%
length = len(r_ids)
res=[None]*length
for i in range(length):
    res[i] = download.resume(r_ids[i])
    res[i] = parse.resume(res[i])
res
# Out:
# Connection error occurred: HTTPSConnectionPool(host='ekaterinburg.hh.ru', port=443): Max retries exceeded with url: /resume/83179d3d0000828a4f0039ed1f736563726574 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x0000018BDC7A7E08>, 'Connection to ekaterinburg.hh.ru timed out. (connect timeout=10)'))
# A second request to the https://hh.ru/resume/83179d3d0000828a4f0039ed1f736563726574 will be sent in 10 seconds
# [{'birth_date': '13\xa0января\xa01978',
#   'gender': 'Мужчина',
#   'area': 'Железнодорожный',
#   'title': 'Руководитель проекта',
#   'specialization': [{'name': 'Деревообработка, Лесная промышленность',
#     'profarea_name': 'Производство, сельское хозяйство'},
#    {'name': 'Стройматериалы',
#     'profarea_name': 'Производство, сельское хозяйство'},
#    {'name': 'Металлургия',
#     'profarea_name': 'Производство, сельское хозяйство'}],
#   'salary': {'amount': 90000, 'currency': 'руб.'},
# ...

# %%
import json
with open('resum.json', 'w', encoding='utf-8') as f:
    json.dump(res, f, ensure_ascii=False, indent=4)

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))': /packages/5f/a5/24db9dd5c4a8b6c8e495289f17c28e55601769798b0e2e5a5aeb2abd247b/numpy-1.19.4-cp37-cp37m-win_amd64.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))': /packages/5f/a5/24db9dd5c4a8b6c8e495289f17c28e55601769798b0e2e5a5aeb2abd247b/numpy-1.19.4-cp37-cp37m-win_amd64.whl
# ...

# %%
import numpy as np
import requests
from tqdm import tqdm_notebook
import pandas as pd
r = requests.get('https://api.hh.ru/vacancies?employer_id=665467').json() 
r
# Out:
# {'items': [{'id': '43925774',
#    'premium': False,
#    'name': 'Аналитик по обработке данных',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '90', 'name': 'Томск', 'url': 'https://api.hh.ru/areas/90'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-04-15T16:21:10+0300',
#    'created_at': '2021-04-15T16:21:10+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=43925774',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/43925774?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/43925774',
#    'relations': [],
#    'employer': {'id': '665467',
#     'name': 'Гринатом',
#     'url': 'https://api.hh.ru/employers/665467',
#     'alternate_url': 'https://hh.ru/employer/665467',
# ...

# %%
import tqdm as tqdm
vac = []
for i in tqdm_notebook(range(0, 5)):
    vac.append(requests.get("https://api.hh.ru/vacancies?employer_id=665467", params={'page': i, 'per_page':20}).json())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-cfe5882c7f55> in <module>
#       1 import tqdm as tqdm
#       2 vac = []
# ----> 3 for i in tqdm_notebook(range(0, 5)):
#       4     vac.append(requests.get("https://api.hh.ru/vacancies?employer_id=665467", params={'page': i, 'per_page':20}).json())
#
# NameError: name 'tqdm_notebook' is not defined

# %%
import pandas as pd
import json

df = pd.read_json('vac_one_json.json')

print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-5a46f4027537> in <module>
#       2 import json
#       3
# ----> 4 df = pd.read_json('vac_one_json.json')
#       5
#       6 print(df.to_string())
#
# ~\Miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\Miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...
